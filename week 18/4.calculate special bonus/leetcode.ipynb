# %%
import pandas as pd

# %%
data = [[3, 'Meir', 3000], [2, 'Michael', 3800], [7, 'Addilyn', 7400], [8, 'Juan', 6100], [9, 'Kannon', 7700]]
employees = pd.DataFrame(data, columns=['employee_id', 'name', 'salary']).astype({'employee_id':'int64', 'name':'object', 'salary':'int64'})

# %%
employees
# Out:
#    employee_id     name  salary
# 0            3     Meir    3000
# 1            2  Michael    3800
# 2            7  Addilyn    7400
# 3            8     Juan    6100
# 4            9   Kannon    7700

# %%
employees['bonus'] = employees.apply(lambda row: row['salary'] if row['employee_id'] % 2 != 0 and not row['name'].startswith('M') else 0, axis=1)

# %%
employees[['employee_id', 'bonus']].sort_values(by='employee_id')
# Out:
#    employee_id  bonus
# 1            2      0
# 0            3      0
# 2            7   7400
# 3            8      0
# 4            9   7700
