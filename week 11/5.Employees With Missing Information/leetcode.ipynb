# %%
import pandas as pd

# %%
data = [[2, 'Crew'], [4, 'Haven'], [5, 'Kristian']]
employees = pd.DataFrame(data, columns=['employee_id', 'name']).astype({'employee_id':'Int64', 'name':'object'})
data = [[5, 76071], [1, 22517], [4, 63539]]
salaries = pd.DataFrame(data, columns=['employee_id', 'salary']).astype({'employee_id':'Int64', 'salary':'Int64'})

# %%
employees
# Out:
#    employee_id      name
# 0            2      Crew
# 1            4     Haven
# 2            5  Kristian

# %%
salaries
# Out:
#    employee_id  salary
# 0            5   76071
# 1            1   22517
# 2            4   63539

# %%
df = pd.merge(employees, salaries, how='outer', on='employee_id')

# %%
df
# Out:
#    employee_id      name  salary
# 0            2      Crew    <NA>
# 1            4     Haven   63539
# 2            5  Kristian   76071
# 3            1       NaN   22517

# %%
pd.DataFrame(df[df['name'].isnull() | df['salary'].isnull()]['employee_id'].sort_values())
# Out:
#    employee_id
# 3            1
# 0            2
