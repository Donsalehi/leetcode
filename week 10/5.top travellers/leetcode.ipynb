# %%
import pandas as pd

# %%
data = [[1, 'Alice'], [2, 'Bob'], [3, 'Alex'], [4, 'Donald'], [7, 'Lee'], [13, 'Jonathan'], [19, 'Elvis']]
users = pd.DataFrame(data, columns=['id', 'name']).astype({'id':'Int64', 'name':'object'})
data = [[1, 1, 120], [2, 2, 317], [3, 3, 222], [4, 7, 100], [5, 13, 312], [6, 19, 50], [7, 7, 120], [8, 19, 400], [9, 7, 230]]
rides = pd.DataFrame(data, columns=['id', 'user_id', 'distance']).astype({'id':'Int64', 'user_id':'Int64', 'distance':'Int64'})

# %%
users
# Out:
#    id      name
# 0   1     Alice
# 1   2       Bob
# 2   3      Alex
# 3   4    Donald
# 4   7       Lee
# 5  13  Jonathan
# 6  19     Elvis

# %%
rides
# Out:
#    id  user_id  distance
# 0   1        1       120
# 1   2        2       317
# 2   3        3       222
# 3   4        7       100
# 4   5       13       312
# 5   6       19        50
# 6   7        7       120
# 7   8       19       400
# 8   9        7       230

# %%
df = pd.merge(users, rides, left_on='id', right_on='user_id', how='left').groupby(['id_x', 'name']).agg(travelled_distance=('distance', 'sum')).reset_index() \
              .drop('id_x',axis=1) \
              .sort_values(by=['travelled_distance', 'name'], ascending=[False, True])

# %%
df
# Out:
#        name  travelled_distance
# 6     Elvis                 450
# 4       Lee                 450
# 1       Bob                 317
# 5  Jonathan                 312
# 2      Alex                 222
# 0     Alice                 120
# 3    Donald                   0
